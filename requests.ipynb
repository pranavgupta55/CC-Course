# %%
# dependencies

# %pip install anthropic python-dotenv

# %%
# env

from dotenv import load_dotenv

load_dotenv()

# %%
# create a client

from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# make a request

message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "What is quantum computing? Answer in one sentence"
        }
    ]
)

# %%
message.content[0].text
# Out:
# 'Quantum computing uses quantum bits (qubits) that exploit superposition and entanglement to process information in fundamentally different ways than classical computers, potentially solving certain problems exponentially faster.'

# %%
# 3 helper funcs

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "be concise. which model are you")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "when is your knowledge cut off")

# Get the follow-up response with full context
final_answer = chat(messages)

# %%
print(answer)
print(final_answer)
# Out:
# I'm Claude, made by Anthropic. I don't know my exact version number, but I'm one of the recent Claude models.
# April 2024.
